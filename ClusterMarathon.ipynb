# %%
import numpy as np
import pandas as pd
import matplotlib as plot
from marplot import toto
import matplotlib.pyplot as plt
from kmodes.kprototypes import KPrototypes

data = pd.read_csv('SkopjeMaraton2019.csv', delimiter = ',')
fivemale = data[(data['Marathon Type'] == '5K') & (data['Gender'] == 'M')]

# %%
fivemale = fivemale.drop(['Bib','Name', 'Firstname', 'Gun time', 'Chip time', 'Marathon Type', 'Gender'],axis=1)

# %%
fivemale
# Out:
#        Rank Country  Chip time in minutes                    Club
# 0       1.0     MKD                 17.87                     NaN
# 1       1.0     MKD                 17.85                   FFOSZ
# 2       3.0     MKD                 17.95                   DELTA
# 3       4.0     MKD                 18.03       AK OLIMP - BITOLA
# 4       5.0     MKD                 18.50                   DELTA
# 5       6.0     MKD                 18.82                  BTOBET
# 6       7.0     ALB                 19.47                     NaN
# 7       9.0     SRB                 19.83  ARK MARATONAC KRUSEVAC
# 8       8.0     MKD                 19.85                  TIKVES
# 9      10.0     MKD                 20.15                  SEAVUS
# 10     11.0     MKD                 20.22                     NaN
# 11     12.0     MKD                 20.33                   DELTA
# 12     13.0     MKD                 20.47               AK VARDAR
# 13     14.0     MKD                 20.73          FON UNIVERSITY
# 15     15.0     MKD                 20.82                   DELTA
# 16     16.0     MKD                 21.13                   DELTA
# 17     17.0     MKD                 21.13                     NaN
# 18     18.0     MKD                 21.10       ZAN MITREV CLINIC
# 20     19.0     MKD                 21.07                     NaN
# 21     20.0     MKD                 21.25                     NaN
# 22     21.0     MKD                 21.47   NRC - NIKE + RUN CLUB
# 23     22.0     MKD                 21.28                   APTIV
# 24     23.0     MKD                 21.90                     NaN
# 25     24.0     MKD                 21.97                     NaN
# 27     25.0     MKD                 22.20                     NaN
# 28     26.0     MKD                 22.58                     NaN
# 29     27.0     MKD                 22.72                     NaN
# 30     28.0     MKD                 22.77                     NaN
# 31     29.0     USA                 22.95                     NaN
# 32     30.0     MKD                 23.23                     NaN
# ...     ...     ...                   ...                     ...
# 11830   NaN     MKD                  0.00                     NaN
# 11832   NaN     MKD                  0.00                     NaN
# 11833   NaN     MKD                  0.00                     NaN
# 11834   NaN     MKD                  0.00                     NaN
# 11839   NaN     MKD                  0.00                     NaN
# 11840   NaN     MKD                  0.00                     NaN
# 11843   NaN     MKD                  0.00                     NaN
# 11844   NaN     MKD                  0.00                     NaN
# 11846   NaN     MKD                  0.00                     NaN
# 11847   NaN     MKD                  0.00                     NaN
# 11848   NaN     MKD                  0.00                     NaN
# 11849   NaN     MKD                  0.00                     NaN
# 11850   NaN     MKD                  0.00                     NaN
# 11851   NaN     MKD                  0.00                     NaN
# 11854   NaN     MKD                  0.00                     NaN
# 11857   NaN     MKD                  0.00                     NaN
# 11858   NaN     MKD                  0.00                     NaN
# 11862   NaN     MKD                  0.00                     NaN
# 11865   NaN     MKD                  0.00                     NaN
# 11866   NaN     MKD                  0.00                     NaN
# 11873   NaN     MKD                  0.00                     NaN
# 11874   NaN     MKD                  0.00                     NaN
# 11875   NaN     MKD                  0.00                     NaN
# 11876   NaN     MKD                  0.00                     NaN
# 11881   NaN     MKD                  0.00                     NaN
# 11888   NaN     MKD                  0.00                     NaN
# 11889   NaN     MKD                  0.00                     NaN
# 11890   NaN     MKD                  0.00                     NaN
# 12033   NaN     MKD                  0.00                     NaN
# 12034   NaN     MKD                  0.00                     NaN
#
# [4468 rows x 4 columns]

# %%
a = (fivemale['Rank'])
fivemale = fivemale.dropna()

# %%
kproto = KPrototypes(n_clusters=4, init='Cao', verbose=2)
clusters = kproto.fit_predict(fivemale, categorical=[0, 1, 3])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 905, ncost: 41695.58294803566
# Run: 1, iteration: 2/100, moves: 318, ncost: 40332.79276982052
# Run: 1, iteration: 3/100, moves: 151, ncost: 40077.91171684648
# Run: 1, iteration: 4/100, moves: 73, ncost: 40030.691653881084
# Run: 1, iteration: 5/100, moves: 23, ncost: 40024.70114409938
# Run: 1, iteration: 6/100, moves: 11, ncost: 40021.9863667503
# Run: 1, iteration: 7/100, moves: 10, ncost: 40019.93919067655
# Run: 1, iteration: 8/100, moves: 9, ncost: 40018.33714301003
# Run: 1, iteration: 9/100, moves: 4, ncost: 40018.00129320866
# Run: 1, iteration: 10/100, moves: 9, ncost: 40016.38695111875
# Run: 1, iteration: 11/100, moves: 6, ncost: 40015.684710736015
# Run: 1, iteration: 12/100, moves: 1, ncost: 40015.659319856364
# Run: 1, iteration: 13/100, moves: 0, ncost: 40015.659319856364
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 698, ncost: 46233.55914583641
# Run: 2, iteration: 2/100, moves: 369, ncost: 42982.0178358148
# Run: 2, iteration: 3/100, moves: 243, ncost: 41681.71217007583
# Run: 2, iteration: 4/100, moves: 208, ncost: 40900.02628115515
# Run: 2, iteration: 5/100, moves: 132, ncost: 40544.53708025222
# Run: 2, iteration: 6/100, moves: 131, ncost: 40247.27995208245
# Run: 2, iteration: 7/100, moves: 93, ncost: 40084.10651957743
# Run: 2, iteration: 8/100, moves: 71, ncost: 39975.1729571981
# Run: 2, iteration: 9/100, moves: 43, ncost: 39930.576114002666
# Run: 2, iteration: 10/100, moves: 28, ncost: 39915.01811757779
# Run: 2, iteration: 11/100, moves: 29, ncost: 39900.27113171883
# Run: 2, iteration: 12/100, moves: 18, ncost: 39894.973772719924
# Run: 2, iteration: 13/100, moves: 6, ncost: 39892.51997782909
# Run: 2, iteration: 14/100, moves: 4, ncost: 39891.6388165672
# Run: 2, iteration: 15/100, moves: 8, ncost: 39890.1326161067
# Run: 2, iteration: 16/100, moves: 3, ncost: 39889.93363619478
# Run: 2, iteration: 17/100, moves: 6, ncost: 39889.02515541053
# Run: 2, iteration: 18/100, moves: 3, ncost: 39888.78894744066
# Run: 2, iteration: 19/100, moves: 1, ncost: 39888.767120861536
# Run: 2, iteration: 20/100, moves: 0, ncost: 39888.767120861536
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 570, ncost: 43307.95025647216
# Run: 3, iteration: 2/100, moves: 299, ncost: 41521.765066267966
# Run: 3, iteration: 3/100, moves: 220, ncost: 40679.33961889055
# Run: 3, iteration: 4/100, moves: 144, ncost: 40315.93845392981
# Run: 3, iteration: 5/100, moves: 109, ncost: 40115.310381707604
# Run: 3, iteration: 6/100, moves: 74, ncost: 39993.422653118294
# Run: 3, iteration: 7/100, moves: 55, ncost: 39933.48820067431
# Run: 3, iteration: 8/100, moves: 31, ncost: 39915.52322470221
# Run: 3, iteration: 9/100, moves: 30, ncost: 39900.27113171884
# Run: 3, iteration: 10/100, moves: 18, ncost: 39894.973772719924
# Run: 3, iteration: 11/100, moves: 6, ncost: 39892.519977829026
# Run: 3, iteration: 12/100, moves: 4, ncost: 39891.6388165672
# Run: 3, iteration: 13/100, moves: 8, ncost: 39890.1326161067
# Run: 3, iteration: 14/100, moves: 3, ncost: 39889.93363619475
# Run: 3, iteration: 15/100, moves: 6, ncost: 39889.02515541051
# Run: 3, iteration: 16/100, moves: 3, ncost: 39888.788947440655
# Run: 3, iteration: 17/100, moves: 1, ncost: 39888.76712086152
# Run: 3, iteration: 18/100, moves: 0, ncost: 39888.76712086152
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 351, ncost: 41397.03126771856
# Run: 4, iteration: 2/100, moves: 176, ncost: 40741.37514877487
# Run: 4, iteration: 3/100, moves: 128, ncost: 40407.34228167916
# Run: 4, iteration: 4/100, moves: 119, ncost: 40167.38680965878
# Run: 4, iteration: 5/100, moves: 81, ncost: 40032.177927253215
# Run: 4, iteration: 6/100, moves: 63, ncost: 39949.72477966394
# Run: 4, iteration: 7/100, moves: 41, ncost: 39918.86804807815
# Run: 4, iteration: 8/100, moves: 28, ncost: 39905.800326040226
# Run: 4, iteration: 9/100, moves: 22, ncost: 39895.34265646833
# Run: 4, iteration: 10/100, moves: 10, ncost: 39892.51997782911
# Run: 4, iteration: 11/100, moves: 4, ncost: 39891.63881656715
# Run: 4, iteration: 12/100, moves: 8, ncost: 39890.13261610668
# Run: 4, iteration: 13/100, moves: 3, ncost: 39889.93363619478
# Run: 4, iteration: 14/100, moves: 6, ncost: 39889.0251554105
# Run: 4, iteration: 15/100, moves: 3, ncost: 39888.78894744068
# Run: 4, iteration: 16/100, moves: 1, ncost: 39888.767120861514
# Run: 4, iteration: 17/100, moves: 0, ncost: 39888.767120861514
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 257, ncost: 40654.84313883562
# Run: 5, iteration: 2/100, moves: 150, ncost: 40323.79253531116
# Run: 5, iteration: 3/100, moves: 95, ncost: 40187.60874754096
# Run: 5, iteration: 4/100, moves: 63, ncost: 40135.331874176205
# Run: 5, iteration: 5/100, moves: 38, ncost: 40104.59644418678
# Run: 5, iteration: 6/100, moves: 34, ncost: 40085.436747755026
# Run: 5, iteration: 7/100, moves: 18, ncost: 40080.12723012889
# Run: 5, iteration: 8/100, moves: 13, ncost: 40077.01998704451
# Run: 5, iteration: 9/100, moves: 17, ncost: 40071.43619166582
# Run: 5, iteration: 10/100, moves: 51, ncost: 40030.77042754795
# Run: 5, iteration: 11/100, moves: 22, ncost: 40024.166727588985
# Run: 5, iteration: 12/100, moves: 11, ncost: 40021.52680796897
# Run: 5, iteration: 13/100, moves: 10, ncost: 40019.55190862212
# Run: 5, iteration: 14/100, moves: 9, ncost: 40018.159204687196
# Run: 5, iteration: 15/100, moves: 2, ncost: 40018.00129320867
# Run: 5, iteration: 16/100, moves: 9, ncost: 40016.38695111873
# Run: 5, iteration: 17/100, moves: 6, ncost: 40015.68471073587
# Run: 5, iteration: 18/100, moves: 1, ncost: 40015.65931985623
# Run: 5, iteration: 19/100, moves: 0, ncost: 40015.65931985623
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 315, ncost: 40721.365769237935
# Run: 6, iteration: 2/100, moves: 177, ncost: 40240.799325212436
# Run: 6, iteration: 3/100, moves: 124, ncost: 40000.42694032003
# Run: 6, iteration: 4/100, moves: 63, ncost: 39931.95896815882
# Run: 6, iteration: 5/100, moves: 29, ncost: 39915.5232247023
# Run: 6, iteration: 6/100, moves: 30, ncost: 39900.271131718786
# Run: 6, iteration: 7/100, moves: 18, ncost: 39894.97377271988
# Run: 6, iteration: 8/100, moves: 6, ncost: 39892.519977829084
# Run: 6, iteration: 9/100, moves: 4, ncost: 39891.63881656719
# Run: 6, iteration: 10/100, moves: 8, ncost: 39890.1326161067
# Run: 6, iteration: 11/100, moves: 3, ncost: 39889.933636194815
# Run: 6, iteration: 12/100, moves: 6, ncost: 39889.02515541051
# Run: 6, iteration: 13/100, moves: 3, ncost: 39888.788947440655
# Run: 6, iteration: 14/100, moves: 1, ncost: 39888.76712086154
# Run: 6, iteration: 15/100, moves: 0, ncost: 39888.76712086154
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 554, ncost: 45301.686915247265
# Run: 7, iteration: 2/100, moves: 337, ncost: 42582.8239124584
# Run: 7, iteration: 3/100, moves: 250, ncost: 41352.3073476266
# Run: 7, iteration: 4/100, moves: 219, ncost: 40620.5269042065
# Run: 7, iteration: 5/100, moves: 114, ncost: 40394.7269609316
# Run: 7, iteration: 6/100, moves: 105, ncost: 40230.25958713808
# Run: 7, iteration: 7/100, moves: 80, ncost: 40149.633102889835
# Run: 7, iteration: 8/100, moves: 46, ncost: 40114.43427948246
# Run: 7, iteration: 9/100, moves: 42, ncost: 40087.61357413326
# Run: 7, iteration: 10/100, moves: 23, ncost: 40080.127230128885
# Run: 7, iteration: 11/100, moves: 13, ncost: 40077.01998704451
# Run: 7, iteration: 12/100, moves: 17, ncost: 40071.436191665896
# Run: 7, iteration: 13/100, moves: 51, ncost: 40030.770427547985
# Run: 7, iteration: 14/100, moves: 22, ncost: 40024.16672758901
# Run: 7, iteration: 15/100, moves: 11, ncost: 40021.52680796894
# Run: 7, iteration: 16/100, moves: 10, ncost: 40019.551908622074
# Run: 7, iteration: 17/100, moves: 9, ncost: 40018.15920468715
# Run: 7, iteration: 18/100, moves: 2, ncost: 40018.00129320868
# Run: 7, iteration: 19/100, moves: 9, ncost: 40016.38695111872
# Run: 7, iteration: 20/100, moves: 6, ncost: 40015.68471073592
# Run: 7, iteration: 21/100, moves: 1, ncost: 40015.659319856284
# Run: 7, iteration: 22/100, moves: 0, ncost: 40015.659319856284
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 753, ncost: 42988.85922862916
# Run: 8, iteration: 2/100, moves: 343, ncost: 40969.166011567715
# Run: 8, iteration: 3/100, moves: 186, ncost: 40358.28161128263
# Run: 8, iteration: 4/100, moves: 121, ncost: 40096.926306283945
# Run: 8, iteration: 5/100, moves: 78, ncost: 39979.74304566272
# Run: 8, iteration: 6/100, moves: 50, ncost: 39929.223979537375
# Run: 8, iteration: 7/100, moves: 26, ncost: 39915.01811757779
# Run: 8, iteration: 8/100, moves: 29, ncost: 39900.271131718786
# Run: 8, iteration: 9/100, moves: 18, ncost: 39894.9737727199
# Run: 8, iteration: 10/100, moves: 6, ncost: 39892.5199778291
# Run: 8, iteration: 11/100, moves: 4, ncost: 39891.638816567145
# Run: 8, iteration: 12/100, moves: 8, ncost: 39890.132616106675
# Run: 8, iteration: 13/100, moves: 3, ncost: 39889.93363619474
# Run: 8, iteration: 14/100, moves: 6, ncost: 39889.0251554105
# Run: 8, iteration: 15/100, moves: 3, ncost: 39888.78894744065
# Run: 8, iteration: 16/100, moves: 1, ncost: 39888.76712086153
# Run: 8, iteration: 17/100, moves: 0, ncost: 39888.76712086153
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 521, ncost: 41206.0313804594
# Run: 9, iteration: 2/100, moves: 283, ncost: 40129.17352446742
# Run: 9, iteration: 3/100, moves: 120, ncost: 39929.17274560643
# Run: 9, iteration: 4/100, moves: 39, ncost: 39906.86165955005
# Run: 9, iteration: 5/100, moves: 24, ncost: 39893.04967903775
# Run: 9, iteration: 6/100, moves: 9, ncost: 39891.42362489546
# Run: 9, iteration: 7/100, moves: 8, ncost: 39890.058855157826
# Run: 9, iteration: 8/100, moves: 4, ncost: 39889.76010097335
# Run: 9, iteration: 9/100, moves: 6, ncost: 39888.8506043792
# Run: 9, iteration: 10/100, moves: 2, ncost: 39888.767120861485
# Run: 9, iteration: 11/100, moves: 0, ncost: 39888.767120861485
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 528, ncost: 49505.251943019524
# Run: 10, iteration: 2/100, moves: 498, ncost: 44858.20772990122
# Run: 10, iteration: 3/100, moves: 367, ncost: 42557.480544326216
# Run: 10, iteration: 4/100, moves: 274, ncost: 41325.576838395544
# Run: 10, iteration: 5/100, moves: 214, ncost: 40619.316598605874
# Run: 10, iteration: 6/100, moves: 115, ncost: 40393.06142527333
# Run: 10, iteration: 7/100, moves: 105, ncost: 40228.91440654653
# Run: 10, iteration: 8/100, moves: 79, ncost: 40149.633102889864
# Run: 10, iteration: 9/100, moves: 46, ncost: 40114.43427948243
# Run: 10, iteration: 10/100, moves: 42, ncost: 40087.61357413327
# Run: 10, iteration: 11/100, moves: 23, ncost: 40080.12723012883
# Run: 10, iteration: 12/100, moves: 13, ncost: 40077.019987044536
# Run: 10, iteration: 13/100, moves: 17, ncost: 40071.436191665875
# Run: 10, iteration: 14/100, moves: 51, ncost: 40030.77042754796
# Run: 10, iteration: 15/100, moves: 22, ncost: 40024.166727589065
# Run: 10, iteration: 16/100, moves: 11, ncost: 40021.52680796901
# Run: 10, iteration: 17/100, moves: 10, ncost: 40019.5519086221
# Run: 10, iteration: 18/100, moves: 9, ncost: 40018.159204687196
# Run: 10, iteration: 19/100, moves: 2, ncost: 40018.00129320871
# Run: 10, iteration: 20/100, moves: 9, ncost: 40016.38695111873
# Run: 10, iteration: 21/100, moves: 6, ncost: 40015.68471073591
# Run: 10, iteration: 22/100, moves: 1, ncost: 40015.659319856284
# Run: 10, iteration: 23/100, moves: 0, ncost: 40015.659319856284
# Best run was number 9

# %%
print(kproto.cluster_centroids_)
# Out:
# [array([[35.47712088],
#        [29.40912214],
#        [50.45566879],
#        [42.02505279]]), array([['1218.0', 'MKD', 'JMMK'],
#        ['143.0', 'MKD', 'ALKALOID-ZDRAVJETO PRED SE'],
#        ['3386.0', 'MKD', 'AMSM'],
#        ['2243.0', 'MKD', 'JMMK']], dtype='<U32')]
